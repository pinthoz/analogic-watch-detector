# %% [markdown]
# # Yolo - Train a model to detect watch time

# %%
yolo task=detect mode=train data=dataset.yaml model=yolo11n.pt epochs=100 imgsz=640 device=0 lr0=1e-4 momentum=0.85 weight_decay=1e-5
# Out:
# ^C
# Ultralytics 8.3.39 🚀 Python-3.8.9 torch-2.2.2+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...
